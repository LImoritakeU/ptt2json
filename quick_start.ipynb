# %%
from ptt import *

# %%
ptt = PttPage("Gossiping")
ptt.posts
# Out:
# posts
# [{'url': '/bbs/Gossiping/M.1560591164.A.B9C.html',
#   'post_id': 'M.1560591164.A.B9C',
#   'timestamp': '1560591164',
#   'title': '[新聞] 暴動！財經女神訪歐曬日光浴 白皙長腿惹',
#   'nrec': '',
#   'author': 'cycling',
#   'mark': ''},
#  {'url': '/bbs/Gossiping/M.1560591174.A.B05.html',
#   'post_id': 'M.1560591174.A.B05',
#   'timestamp': '1560591174',
#   'title': '[新聞] 韓國瑜造勢到底多少人? 椅子精算師四叉貓算給你',
#   'nrec': '',
#   'author': 'sweat992001',
#   'mark': ''},
#  {'url': '/bbs/Gossiping/M.1560591182.A.50D.html',
#   'post_id': 'M.1560591182.A.50D',
#   'timestamp': '1560591182',
#   'title': 'Re: [新聞] 大烏龍！攝影師砸30萬修MacBook 最後發現',
#   'nrec': '',
#   'author': 'YHOTV4096',
#   'mark': ''},
#  {'url': '/bbs/Gossiping/M.1560591198.A.576.html',
#   'post_id': 'M.1560591198.A.576',
#   'timestamp': '1560591198',
#   'title': '[爆卦] 韓國瑜:我當總統，台灣絕不可能一國兩制',
#   'nrec': '12',
#   'author': 'Zw111196',
#   'mark': ''},
#  {'url': '/bbs/Gossiping/M.1560591206.A.419.html',
#   'post_id': 'M.1560591206.A.419',
# ...

# %%
ptt.get_prev()
# Out:
# /home/shihhao/workspace/ptt_web_crawler/venv/lib64/python3.7/site-packages/urllib3/connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
ptt.posts
# Out:
# posts
# [{'url': '/bbs/Gossiping/M.1560590561.A.3F2.html',
#   'post_id': 'M.1560590561.A.3F2',
#   'timestamp': '1560590561',
#   'title': '[爆卦] 李佳芬哭了!!!',
#   'nrec': '7',
#   'author': 'ChuckBass',
#   'mark': ''},
#  {'url': '/bbs/Gossiping/M.1560590564.A.277.html',
#   'post_id': 'M.1560590564.A.277',
#   'timestamp': '1560590564',
#   'title': 'Re: [新聞] 大烏龍！攝影師砸30萬修MacBook 最後發現',
#   'nrec': '',
#   'author': 'ReDmango',
#   'mark': ''},
#  {'url': '/bbs/Gossiping/M.1560590590.A.A47.html',
#   'post_id': 'M.1560590590.A.A47',
#   'timestamp': '1560590590',
#   'title': '[問卦] 學校的學士服沒有特色的人在想什麼',
#   'nrec': '1',
#   'author': 'ccxx9999',
#   'mark': ''},
#  {'url': '/bbs/Gossiping/M.1560590595.A.FF0.html',
#   'post_id': 'M.1560590595.A.FF0',
#   'timestamp': '1560590595',
#   'title': '[問卦] 秋行軍蟲有學長學弟制嗎？',
#   'nrec': '1',
#   'author': 'ma4wanderer',
#   'mark': ''},
#  {'url': '/bbs/Gossiping/M.1560590608.A.EAC.html',
#   'post_id': 'M.1560590608.A.EAC',
# ...

# %%
pg: PttPost = PttPost(url="/bbs/Gossiping/M.1560590847.A.3B0.html")

# %%
pg.to_dict()
# Out:
# https://www.ptt.cc/bbs/Gossiping/M.1560590847.A.3B0.html
# {'article_id': 'M.1560590847.A.3B0',
#  'article_title': '[問卦] 急！接到推銷電話怎麼辦？在線等',
#  'author': 'osk2',
#  'board': 'Gossiping',
#  'content': '嗨嗨\n\n是這樣的啦\n\n本魯接到奇怪的推銷電話\n\n推銷員說要他們公司在競賽週，有兩款商品要比誰賣的好\n\n一個是高麗魚乾，說是吃了會招財\n\n另一個是媽祖造型的果凍，按時服用保證變長跑冠軍\n\n\n\n我是覺得都蠻唬爛的啦\n\n有沒有要買哪一種的八卦？\n\n--\n\n這樣是要買招財魚乾的意思嗎',
#  'timestamp': '1560590847',
#  'ip': '114.33.181.85',
#  'message_count': {'all': 13, 'boo': 0, 'count': 3, 'neutral': 10, 'push': 3},
#  'messages': [{'push_tag': '→',
#    'push_userid': 'shevchen',
#    'push_content': '約炮ㄚ',
#    'push_ipdatetime': '111.253.227.75 06/15 17:27'},
#   {'push_tag': '推',
#    'push_userid': 'Dreamer48763',
#    'push_content': '跟他說你韓粉',
#    'push_ipdatetime': '180.217.124.55 06/15 17:27'},
#   {'push_tag': '→',
#    'push_userid': 'tigerblue663',
#    'push_content': '唬回去',
#    'push_ipdatetime': '1.168.208.23 06/15 17:28'},
#   {'push_tag': '推',
#    'push_userid': 'tim8177414',
# ...

# %%
# Out:
# 臺灣

# %%
# Out:
# ''
